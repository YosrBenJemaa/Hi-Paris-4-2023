# %% [markdown]
# ## 1/ Merging datasets: adding new features

# %%
import pandas as pd
from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv('./Datasets/train-data.csv', delimiter=';')

# %%
#Change the names of countries that are in the training data to real names (this will be applied to all datasets)
country_mapping = {'DE': "Germany",
'CN': "China",
'GB': "United Kingdom",
'AU': "Australia",
'ES': "Spain",
'NL': "Netherlands",
'US': "United States",
'DK': "Denmark",
'BE': "Belgium",
'FR': "France",
'IT': "Italy",
'PL': "Poland",
'SE': "Sweden",
'TW': "Taiwan",
'JP': "Japan",
'HK': "Hong Kong",
'KR': "South Korea",
'PH': "Philippines",
'MY': "Malaysia",
'SG': "Singapore",
'TH': "Thailand",
'ID': "Indonesia",
'FJ': "Fiji",
'VN': "Vietnam",
'BN': "Brunei",
'NZ': "New Zealand",
'MM': "Myanmar",
'KH': "Cambodia",
'MN': "Mongolia",
'LA': "Laos",
'PG': "Papua New Guinea"}
for original, replacement in country_mapping.items():
    df['Country'] = df['Country'].replace(original, replacement)

# %%
######## LPIextend

# %%
lpiextend = pd.read_csv('./Datasets/Other datasets/LPIextend.csv', delimiter=',')

# %%
cleaned_countries = [country.split(',')[0].strip() for country in lpiextend["Country"].unique()]

# %%
country_mapping = dict(zip(lpiextend["Country"].unique(), cleaned_countries))
country_mapping["Taiwan, Chnia"] = "China" #Particular Case

# %%
for original, replacement in country_mapping.items():
    lpiextend['Country'] = lpiextend['Country'].replace(original, replacement)

# %%
filtered_lpiextend = lpiextend[lpiextend["Country"].isin(df["Country"].unique())] #We choose the countries that are only in the training data

# %%
lpiextend2 = filtered_lpiextend[['population (2023)', 'Country', 'growthRate', 'landAreaKm']]  # We choose relevant features

# %%
lpiextend2 = lpiextend2[lpiextend2['Country'] != 'Taiwan']  #Cas particulier

# %%
######## Economic

# %%
economic = pd.read_csv('./Datasets/Other datasets/worldbank_economic_data.csv', delimiter=',')

# %%
cleaned_countries2 = [country.split(',')[0].strip() for country in economic["Country"].unique()]

# %%
country_mapping2 = dict(zip(economic["Country"].unique(), cleaned_countries2))
country_mapping2["Taiwan, Chnia"] = "China"

# %%
for original, replacement in country_mapping2.items():
    economic['Country'] = economic['Country'].replace(original, replacement)

# %%
filtered_economic = economic[economic["Country"].isin(df["Country"].unique())]

# %%
economic2 = filtered_economic[['Country', 'Year', 'GDP (current US$)', 'Gross capital formation (annual % growth)', 'Manufacturing, value added (annual % growth)']]

# %%
########## Imputing missing values in the subsets

# %%
imputer = SimpleImputer(strategy='mean')
columns_to_impute = ['GDP (current US$)', 'Gross capital formation (annual % growth)', 'Manufacturing, value added (annual % growth)']
economic2[columns_to_impute] = imputer.fit_transform(economic2[columns_to_impute])
# Out:
# /tmp/ipykernel_547/3090488186.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   economic2[columns_to_impute] = imputer.fit_transform(economic2[columns_to_impute])

# %%
########## Merging

# %%
economic = economic2
lpiextend = lpiextend2

# %%
##### First, we need to create new columns in the training dataframe that contains the Year separately. (Year is the column used for merging)

# %%
df['Year'] = pd.to_numeric(df['Date'].str.extract(r'(\d{4})')[0], errors='coerce')

# %%
merged_df = pd.merge(df, economic, on=['Country', 'Year'], how='left')

# %%
merged_df2 = pd.merge(merged_df, lpiextend, on='Country', how='left')

# %%
merged_df2.drop(columns='Year', inplace=True)

# %%
#### merging with GSCPI

# %%
data_GSCPI=pd.read_csv('./Datasets/Other datasets/GSCPI_data.csv', delimiter=',')
data_GSCPI=data_GSCPI[['Year-Month','GSCPI']]

# %%
# Split 'Year-Month' column into 'Year' and 'Month'
data_GSCPI[['Year', 'Month']] = data_GSCPI['Year-Month'].str.split('-', expand=True)

# Convert 'Year' and 'Month' columns to integers
data_GSCPI['Year'] = data_GSCPI['Year'].astype(int)
data_GSCPI['Month'] = data_GSCPI['Month'].astype(int)

# %%
df2=data_GSCPI
# Créez une nouvelle colonne "groupe" basée sur les conditions spécifiées
df2['groupe'] = pd.cut(df2['Month'], bins=[0, 4, 8, 12], labels=['1', '5', '9'], include_lowest=True)

# %%
# Groupez par année et groupe, puis effectuez l'agrégation souhaitée (par exemple, la somme)
resultat = df2.groupby(['Year', 'groupe'])['GSCPI'].mean()

# %%
df2.loc[(df2['Year'] == 2020) & (df2['groupe'] == "1"), 'GSCPI'] = '1.747447'
df2.loc[(df2['Year'] == 2020) & (df2['groupe'] == "5"), 'GSCPI'] = '2.221625'
df2.loc[(df2['Year'] == 2020) & (df2['groupe'] == "9"), 'GSCPI'] = '0.784687'
df2.loc[(df2['Year'] == 2021) & (df2['groupe'] == "1"), 'GSCPI'] = '2.030159'
df2.loc[(df2['Year'] == 2021) & (df2['groupe'] == "5"), 'GSCPI'] = '2.957795'
df2.loc[(df2['Year'] == 2021) & (df2['groupe'] == "9"), 'GSCPI'] = '3.897540'
df2.loc[(df2['Year'] == 2022) & (df2['groupe'] == "1"), 'GSCPI'] = '3.117173'
df2.loc[(df2['Year'] == 2022) & (df2['groupe'] == "5"), 'GSCPI'] = '2.052432'
df2.loc[(df2['Year'] == 2022) & (df2['groupe'] == "9"), 'GSCPI'] = '1.111621'
df2.loc[(df2['Year'] == 2023) & (df2['groupe'] == "1"), 'GSCPI'] = '-0.430277'
df2.loc[(df2['Year'] == 2023) & (df2['groupe'] == "5"), 'GSCPI'] = '-1.153880'

# %%
df2['groupe'] = df2['groupe'].astype(int)
df2['GSCPI'] = df2['GSCPI'].astype(float)

# %%
data=merged_df2

# %%
# Adding 'year, starting month and end month' for each row
# Map month names to numeric values

month_mapping = {'jan': 1, 'feb': 2, 'mar': 3, 'apr': 4, 'may': 5, 'jun': 6,
                 'jul': 7, 'aug': 8, 'sep': 9, 'oct': 10, 'nov': 11, 'dec': 12}

# Extract year and month from 'Date' column in df
data[['Start_Month', 'End_Month', 'Year']] = data['Date'].astype('str').str.extract(r'(\w+)-(\w+) (\d+)', expand=True)

# Map month names to numeric values
data['Start_Month'] = data['Start_Month'].map(month_mapping)
data['End_Month'] = data['End_Month'].map(month_mapping)

# Convert year columns to integers
data['Year'] = data['Year'].astype(int)

# %%
df2=df2.drop(['Year-Month','Month'],axis=1)

# %%
df_merged_test=pd.merge(data,df2, left_on=['Year','Start_Month'], right_on=['Year', 'groupe'],how='left')
df_merged_test.head()
# Out:
#     index  id_product  Region  Country            Site         Operations  \
# 0  645874      156160  EUROPE  Germany    NL_DC_Venray  Europe Operations
# 1  645874      156160  EUROPE  Germany    NL_DC_Venray  Europe Operations
# 2  645874      156160  EUROPE  Germany    NL_DC_Venray  Europe Operations
# 3  645874      156160  EUROPE  Germany    NL_DC_Venray  Europe Operations
# 4  469488      224631   CHINA    China  CN_DC_Shanghai   China Operations
#
#          Zone  Cluster  Reference proxy Product  Line proxy  ...  \
# 0        DACH  Germany  reference-13523      Product Line-4  ...
# 1        DACH  Germany  reference-13523      Product Line-4  ...
# 2        DACH  Germany  reference-13523      Product Line-4  ...
# 3        DACH  Germany  reference-13523      Product Line-4  ...
# 4  China & HK    China  reference-12778      Product Line-4  ...
#
#   Gross capital formation (annual % growth)  \
# 0                                      3.50
# 1                                      3.50
# 2                                      3.50
# 3                                      3.50
# 4                                      3.87
#
#   Manufacturing, value added (annual % growth) population (2023) growthRate  \
# 0                                     5.070000      8.329463e+07    -0.0009
# 1                                     5.070000      8.329463e+07    -0.0009
# 2                                     5.070000      8.329463e+07    -0.0009
# 3                                     5.070000      8.329463e+07    -0.0009
# 4                                     1.528281      1.425671e+09    -0.0002
#
#   landAreaKm Start_Month End_Month  Year     GSCPI  groupe
# 0   349390.0           5         8  2021  2.957795       5
# 1   349390.0           5         8  2021  2.957795       5
# 2   349390.0           5         8  2021  2.957795       5
# 3   349390.0           5         8  2021  2.957795       5
# 4  9424702.9           1         4  2021  2.030159       1
#
# [5 rows x 30 columns]

# %%
df_merged_test.drop_duplicates(inplace=True)

# %%
df_merged_test.drop(['Start_Month','End_Month','Year','groupe'],axis=1,inplace=True)

# %%
df_merged_test
# Out:
#             index  id_product  Region         Country                 Site  \
# 0          645874      156160  EUROPE         Germany         NL_DC_Venray
# 4          469488      224631   CHINA           China       CN_DC_Shanghai
# 8          348904      104047  EUROPE  United Kingdom            NL_DC_HLD
# 12        1725822       11823    EAJP       Australia          AU_DC_Perth
# 16         404781      159924  EUROPE           Spain            NL_DC_HLD
# ...           ...         ...     ...             ...                  ...
# 12340940  1445304      221019   CHINA           China            CN_DC_SHD
# 12340994   738575        4004    EAJP       Australia          AU_DC_Perth
# 12341002    68026       68026     NAM   United States  US_DC_Mechanicsburg
# 12341006  1841243      127244  EUROPE           Italy        IT_DC_Venaria
# 12341042   306473       61616     NAM   United States  US_DC_Mechanicsburg
#
#                         Operations            Zone         Cluster  \
# 0                Europe Operations            DACH         Germany
# 4                 China Operations      China & HK           China
# 8                Europe Operations  UK and Ireland  United Kingdom
# 12        International Operations         Pacific       Australia
# 16               Europe Operations          Iberia           Spain
# ...                            ...             ...             ...
# 12340940          China Operations      China & HK           China
# 12340994  International Operations         Pacific       Australia
# 12341002  North America Operations              US             USA
# 12341006         Europe Operations           Italy           Italy
# 12341042  North America Operations              US             USA
#
#           Reference proxy Product  Line proxy  ... Month 2 Month 3 Month 4  \
# 0         reference-13523      Product Line-4  ...       0       0       0
# 4         reference-12778      Product Line-4  ...       1       0       0
# 8          reference-3513      Product Line-3  ...       2       0       0
# 12          reference-672      Product Line-1  ...       0       0       0
# 16         reference-3496      Product Line-3  ...       0       0       0
# ...                   ...                 ...  ...     ...     ...     ...
# 12340940  reference-17197      Product Line-2  ...       0       0       0
# 12340994    reference-309      Product Line-1  ...       1       0       0
# 12341002   reference-7393      Product Line-4  ...       1       0       0
# 12341006   reference-8620      Product Line-4  ...       1       0       0
# 12341042   reference-6241      Product Line-4  ...       0       0       0
#
#          GDP (current US$) Gross capital formation (annual % growth)  \
# 0             4.259935e+12                                  3.500000
# 4             1.782046e+13                                  3.870000
# 8             3.122480e+12                                 13.980000
# 12            2.606698e+12                                  3.085818
# 16            1.427381e+12                                  5.860000
# ...                    ...                                       ...
# 12340940      1.796317e+13                                  3.620000
# 12340994      1.552703e+12                                  3.085818
# 12341002      2.106047e+13                                 -3.800000
# 12341006      2.606698e+12                                  3.085818
# 12341042      2.331508e+13                                  6.940000
#
#          Manufacturing, value added (annual % growth) population (2023)  \
# 0                                            5.070000      8.329463e+07
# 4                                            1.528281      1.425671e+09
# 8                                           10.080000      6.773680e+07
# 12                                           1.528281      2.643911e+07
# 16                                           8.910000      4.751963e+07
# ...                                               ...               ...
# 12340940                                     1.528281      1.425671e+09
# 12340994                                     2.240000      2.643911e+07
# 12341002                                    -4.600000      3.399966e+08
# 12341006                                     1.528281      5.887076e+07
# 12341042                                     6.790000      3.399966e+08
#
#          growthRate landAreaKm     GSCPI
# 0           -0.0009   349390.0  2.957795
# 4           -0.0002  9424702.9  2.030159
# 8            0.0034   241930.0  2.030159
# 12           0.0100  7692020.0 -0.430277
# 16          -0.0008   499556.6  2.030159
# ...             ...        ...       ...
# 12340940    -0.0002  9424702.9  2.052432
# 12340994     0.0100  7692020.0  3.897540
# 12341002     0.0050  9147420.0  0.784687
# 12341006    -0.0028   295717.0 -0.430277
# 12341042     0.0050  9147420.0  2.030159
#
# [1762970 rows x 26 columns]

# %% [markdown]
# ## 2/ Cleaning the new dataset

# %%
#Read the data
df_new=df_merged_test

# %%
# Converting months to numerical values
df_new['Month 1'] = df_new['Month 1'].str.replace(' ', '').astype(float)
df_new['Month 2'] = df_new['Month 2'].str.replace(' ', '').astype(float)
df_new['Month 3'] = df_new['Month 3'].str.replace(' ', '').astype(float)
df_new['Month 4'] = df_new['Month 4'].str.replace(' ', '').astype(float)

# %%
# Replacing the NaN value in 'Product Life cycel status' column which means Activelifecycle)
df_new['Product Life cycel status'].fillna('active', inplace=True)

# %% [markdown]
# ### Replacing Missing values

# %% [markdown]
# #### missing values in Month 1 of the original dataset

# %%
may_jul_2023_data = df_new[df_new['Date'] == 'jan-apr 2023'][['id_product','Month 4']]

# Renommer la colonne "Month 4" pour éviter un conflit lors de la fusion
may_jul_2023_data = may_jul_2023_data.rename(columns={'Month 4': 'New_Month_1'})

# Fusionner les deux DataFrames sur la colonne "id_product"
df_new = pd.merge(df_new, may_jul_2023_data, on=['id_product'], how='left')

# Remplacer les valeurs NaN dans "Month 1" par les valeurs correspondantes dans "New_Month_1"
df_new['Month 1'].fillna(df_new['New_Month_1'], inplace=True)

# Supprimer la colonne temporaire "New_Month_1"
df_new.drop(columns=['New_Month_1'], inplace=True)

# %%
df_new['Month 1'].fillna(df_new[['Month 2','Month 3']].mean(axis=1), inplace=True)

# %% [markdown]
# #### missing values in the new added features

# %%
df_new.isna().sum()
# Out:
# index                                               0
# id_product                                          0
# Region                                              0
# Country                                             0
# Site                                                0
# Operations                                          0
# Zone                                                0
# Cluster                                             0
# Reference proxy                                     0
# Product  Line proxy                                 0
# Division proxy                                      0
# Customer Persona proxy                              0
# Strategic Product Family proxy                      0
# Product Life cycel status                           0
# Date                                                0
# Month 1                                             0
# Month 2                                             0
# Month 3                                             0
# Month 4                                             0
# GDP (current US$)                                   0
# Gross capital formation (annual % growth)       26912
# Manufacturing, value added (annual % growth)    26912
# population (2023)                               11928
# growthRate                                      11928
# landAreaKm                                      11928
# GSCPI                                               0
# dtype: int64

# %%
gdp= df_new[['GDP (current US$)']].mean()
gdp
# Out:
# GDP (current US$)    6.405325e+12
# dtype: float64

# %%
df_new['GDP (current US$)'].fillna(6.405325e+12,inplace=True)

# %%
gc= df_new[['Gross capital formation (annual % growth)']].mean()
gc
# Out:
# Gross capital formation (annual % growth)    4.167608
# dtype: float64

# %%
df_new['Gross capital formation (annual % growth)'].fillna(4.167608, inplace=True)

# %%
mv= df_new[['Manufacturing, value added (annual % growth)']].mean()
mv
# Out:
# Manufacturing, value added (annual % growth)    2.325467
# dtype: float64

# %%
df_new['Manufacturing, value added (annual % growth)'].fillna(2.325467, inplace=True)

# %%
pop = df_new[['population (2023)']].mean()
gRate = df_new[['growthRate']].mean()
lKm = df_new[['landAreaKm']].mean()

# %%
pop
# Out:
# population (2023)    2.272018e+08
# dtype: float64

# %%
gRate
# Out:
# growthRate    0.004524
# dtype: float64

# %%
lKm
# Out:
# landAreaKm    3.918378e+06
# dtype: float64

# %%
df_new['population (2023)'].fillna(2.272018e+08, inplace=True)
df_new['growthRate'].fillna(0.004524, inplace=True)
df_new['landAreaKm'].fillna(3.918378e+06, inplace=True)

# %%
df_new.isna().sum()
# Out:
# index                                           0
# id_product                                      0
# Region                                          0
# Country                                         0
# Site                                            0
# Operations                                      0
# Zone                                            0
# Cluster                                         0
# Reference proxy                                 0
# Product  Line proxy                             0
# Division proxy                                  0
# Customer Persona proxy                          0
# Strategic Product Family proxy                  0
# Product Life cycel status                       0
# Date                                            0
# Month 1                                         0
# Month 2                                         0
# Month 3                                         0
# Month 4                                         0
# GDP (current US$)                               0
# Gross capital formation (annual % growth)       0
# Manufacturing, value added (annual % growth)    0
# population (2023)                               0
# growthRate                                      0
# landAreaKm                                      0
# GSCPI                                           0
# dtype: int64

# %%
df_new.drop(['index'],axis=1,inplace=True)

# %% [markdown]
# #### Removing highly-correlated features ('Region','Country','Site','Operations','Zone' ) with 'Cluster'

# %%
df_new.drop(['Region','Country','Site','Operations','Zone'],axis=1,inplace=True)

# %%
df_new
# Out:
#          id_product         Cluster  Reference proxy Product  Line proxy  \
# 0            156160         Germany  reference-13523      Product Line-4
# 1            224631           China  reference-12778      Product Line-4
# 2            104047  United Kingdom   reference-3513      Product Line-3
# 3             11823       Australia    reference-672      Product Line-1
# 4            159924           Spain   reference-3496      Product Line-3
# ...             ...             ...              ...                 ...
# 1762965      221019           China  reference-17197      Product Line-2
# 1762966        4004       Australia    reference-309      Product Line-1
# 1762967       68026             USA   reference-7393      Product Line-4
# 1762968      127244           Italy   reference-8620      Product Line-4
# 1762969       61616             USA   reference-6241      Product Line-4
#
#         Division proxy    Customer Persona proxy  \
# 0           Division-3   Customer Segmentation-3
# 1           Division-3  Customer Segmentation-14
# 2           Division-2  Customer Segmentation-23
# 3           Division-1  Customer Segmentation-11
# 4           Division-2  Customer Segmentation-14
# ...                ...                       ...
# 1762965     Division-2  Customer Segmentation-28
# 1762966     Division-1   Customer Segmentation-8
# 1762967     Division-3   Customer Segmentation-4
# 1762968     Division-3   Customer Segmentation-4
# 1762969     Division-3  Customer Segmentation-46
#
#         Strategic Product Family proxy Product Life cycel status  \
# 0          Strategic Product Family-12                    active
# 1           Strategic Product Family-9                    active
# 2           Strategic Product Family-7                    active
# 3           Strategic Product Family-3                    active
# 4           Strategic Product Family-7                    active
# ...                                ...                       ...
# 1762965     Strategic Product Family-5                    active
# 1762966     Strategic Product Family-3                       EOL
# 1762967     Strategic Product Family-9                    active
# 1762968    Strategic Product Family-12                    active
# 1762969    Strategic Product Family-12                    active
#
#                  Date  Month 1  Month 2  Month 3  Month 4  GDP (current US$)  \
# 0        may-aug 2021      0.0      0.0      0.0      0.0       4.259935e+12
# 1        jan-apr 2021      0.0      1.0      0.0      0.0       1.782046e+13
# 2        jan-apr 2021      0.0      2.0      0.0      0.0       3.122480e+12
# 3        jan-apr 2023      0.0      0.0      0.0      0.0       2.606698e+12
# 4        jan-apr 2021      0.0      0.0      0.0      0.0       1.427381e+12
# ...               ...      ...      ...      ...      ...                ...
# 1762965  may-aug 2022      0.0      0.0      0.0      0.0       1.796317e+13
# 1762966  sep-dec 2021      0.0      1.0      0.0      0.0       1.552703e+12
# 1762967  sep-dec 2020     18.0      1.0      0.0      0.0       2.106047e+13
# 1762968  jan-apr 2023      0.0      1.0      0.0      0.0       2.606698e+12
# 1762969  jan-apr 2021      0.0      0.0      0.0      0.0       2.331508e+13
#
#          Gross capital formation (annual % growth)  \
# 0                                         3.500000
# 1                                         3.870000
# 2                                        13.980000
# 3                                         3.085818
# 4                                         5.860000
# ...                                            ...
# 1762965                                   3.620000
# 1762966                                   3.085818
# 1762967                                  -3.800000
# 1762968                                   3.085818
# 1762969                                   6.940000
#
#          Manufacturing, value added (annual % growth)  population (2023)  \
# 0                                            5.070000       8.329463e+07
# 1                                            1.528281       1.425671e+09
# 2                                           10.080000       6.773680e+07
# 3                                            1.528281       2.643911e+07
# 4                                            8.910000       4.751963e+07
# ...                                               ...                ...
# 1762965                                      1.528281       1.425671e+09
# 1762966                                      2.240000       2.643911e+07
# 1762967                                     -4.600000       3.399966e+08
# 1762968                                      1.528281       5.887076e+07
# 1762969                                      6.790000       3.399966e+08
#
#          growthRate  landAreaKm     GSCPI
# 0           -0.0009    349390.0  2.957795
# 1           -0.0002   9424702.9  2.030159
# 2            0.0034    241930.0  2.030159
# 3            0.0100   7692020.0 -0.430277
# 4           -0.0008    499556.6  2.030159
# ...             ...         ...       ...
# 1762965     -0.0002   9424702.9  2.052432
# 1762966      0.0100   7692020.0  3.897540
# 1762967      0.0050   9147420.0  0.784687
# 1762968     -0.0028    295717.0 -0.430277
# 1762969      0.0050   9147420.0  2.030159
#
# [1762970 rows x 20 columns]

# %%
df_new.to_csv("train_preprocessing_clean.csv", index=False, sep=';')

# %% [markdown]
# ## Test Set Preprocesing

# %%
#################### Test Set preprocessing #####################

# %%
df = pd.read_csv('./Datasets/X_test.csv', delimiter=';')

# %%
#Change the names of countries that are in the training data to real names (this will be applied to all datasets)
country_mapping = {'DE': "Germany",
'CN': "China",
'GB': "United Kingdom",
'AU': "Australia",
'ES': "Spain",
'NL': "Netherlands",
'US': "United States",
'DK': "Denmark",
'BE': "Belgium",
'FR': "France",
'IT': "Italy",
'PL': "Poland",
'SE': "Sweden",
'TW': "Taiwan",
'JP': "Japan",
'HK': "Hong Kong",
'KR': "South Korea",
'PH': "Philippines",
'MY': "Malaysia",
'SG': "Singapore",
'TH': "Thailand",
'ID': "Indonesia",
'FJ': "Fiji",
'VN': "Vietnam",
'BN': "Brunei",
'NZ': "New Zealand",
'MM': "Myanmar",
'KH': "Cambodia",
'MN': "Mongolia",
'LA': "Laos",
'PG': "Papua New Guinea"}
for original, replacement in country_mapping.items():
    df['Country'] = df['Country'].replace(original, replacement)

# %%
######## LPIextend

# %%
lpiextend = pd.read_csv('./Datasets/Other datasets/LPIextend.csv', delimiter=',')

# %%
cleaned_countries = [country.split(',')[0].strip() for country in lpiextend["Country"].unique()]

# %%
country_mapping = dict(zip(lpiextend["Country"].unique(), cleaned_countries))
country_mapping["Taiwan, Chnia"] = "China" #Particular Case

# %%
for original, replacement in country_mapping.items():
    lpiextend['Country'] = lpiextend['Country'].replace(original, replacement)

# %%
filtered_lpiextend = lpiextend[lpiextend["Country"].isin(df["Country"].unique())] #We choose the countries that are only in the training data

# %%
lpiextend2 = filtered_lpiextend[['population (2023)', 'Country', 'growthRate', 'landAreaKm']]  # We choose relevant features

# %%
lpiextend2 = lpiextend2[lpiextend2['Country'] != 'Taiwan']  #Cas particulier

# %%
######## Economic

# %%
economic = pd.read_csv('./Datasets/Other datasets/worldbank_economic_data.csv', delimiter=',')

# %%
cleaned_countries2 = [country.split(',')[0].strip() for country in economic["Country"].unique()]

# %%
country_mapping2 = dict(zip(economic["Country"].unique(), cleaned_countries2))
country_mapping2["Taiwan, Chnia"] = "China"

# %%
for original, replacement in country_mapping2.items():
    economic['Country'] = economic['Country'].replace(original, replacement)

# %%
filtered_economic = economic[economic["Country"].isin(df["Country"].unique())]

# %%
economic2 = filtered_economic[['Country', 'Year', 'GDP (current US$)', 'Gross capital formation (annual % growth)', 'Manufacturing, value added (annual % growth)']]

# %%
########## Imputing missing values in the subsets

# %%
imputer = SimpleImputer(strategy='mean')
columns_to_impute = ['GDP (current US$)', 'Gross capital formation (annual % growth)', 'Manufacturing, value added (annual % growth)']
economic2[columns_to_impute] = imputer.fit_transform(economic2[columns_to_impute])
# Out:
# /tmp/ipykernel_547/3090488186.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   economic2[columns_to_impute] = imputer.fit_transform(economic2[columns_to_impute])

# %%
########## Merging

# %%
economic = economic2
lpiextend = lpiextend2

# %%
##### First, we need to create new columns in the training dataframe that contains the Year separately. (Year is the column used for merging)

# %%
df['Year'] = pd.to_numeric(df['Date'].str.extract(r'(\d{4})')[0], errors='coerce')

# %%
merged_df = pd.merge(df, economic, on=['Country', 'Year'], how='left')

# %%
merged_df2 = pd.merge(merged_df, lpiextend, on='Country', how='left')

# %%
merged_df2.drop(columns='Year', inplace=True)

# %%
#### merging with GSCPI

# %%
data_GSCPI=pd.read_csv('./Datasets/Other datasets/GSCPI_data.csv', delimiter=',')
data_GSCPI=data_GSCPI[['Year-Month','GSCPI']]

# %%
# Split 'Year-Month' column into 'Year' and 'Month'
data_GSCPI[['Year', 'Month']] = data_GSCPI['Year-Month'].str.split('-', expand=True)

# Convert 'Year' and 'Month' columns to integers
data_GSCPI['Year'] = data_GSCPI['Year'].astype(int)
data_GSCPI['Month'] = data_GSCPI['Month'].astype(int)

# %%
df2=data_GSCPI
# Créez une nouvelle colonne "groupe" basée sur les conditions spécifiées
df2['groupe'] = pd.cut(df2['Month'], bins=[0, 4, 8, 12], labels=['1', '5', '9'], include_lowest=True)

# %%
# Groupez par année et groupe, puis effectuez l'agrégation souhaitée (par exemple, la somme)
resultat = df2.groupby(['Year', 'groupe'])['GSCPI'].mean()

# %%
df2.loc[(df2['Year'] == 2020) & (df2['groupe'] == "1"), 'GSCPI'] = '1.747447'
df2.loc[(df2['Year'] == 2020) & (df2['groupe'] == "5"), 'GSCPI'] = '2.221625'
df2.loc[(df2['Year'] == 2020) & (df2['groupe'] == "9"), 'GSCPI'] = '0.784687'
df2.loc[(df2['Year'] == 2021) & (df2['groupe'] == "1"), 'GSCPI'] = '2.030159'
df2.loc[(df2['Year'] == 2021) & (df2['groupe'] == "5"), 'GSCPI'] = '2.957795'
df2.loc[(df2['Year'] == 2021) & (df2['groupe'] == "9"), 'GSCPI'] = '3.897540'
df2.loc[(df2['Year'] == 2022) & (df2['groupe'] == "1"), 'GSCPI'] = '3.117173'
df2.loc[(df2['Year'] == 2022) & (df2['groupe'] == "5"), 'GSCPI'] = '2.052432'
df2.loc[(df2['Year'] == 2022) & (df2['groupe'] == "9"), 'GSCPI'] = '1.111621'
df2.loc[(df2['Year'] == 2023) & (df2['groupe'] == "1"), 'GSCPI'] = '-0.430277'
df2.loc[(df2['Year'] == 2023) & (df2['groupe'] == "5"), 'GSCPI'] = '-1.153880'

# %%
df2['groupe'] = df2['groupe'].astype(int)
df2['GSCPI'] = df2['GSCPI'].astype(float)

# %%
data=merged_df2

# %%
# Adding 'year, starting month and end month' for each row
# Map month names to numeric values

month_mapping = {'jan': 1, 'feb': 2, 'mar': 3, 'apr': 4, 'may': 5, 'jun': 6,
                 'jul': 7, 'aug': 8, 'sep': 9, 'oct': 10, 'nov': 11, 'dec': 12}

# Extract year and month from 'Date' column in df
data[['Start_Month', 'End_Month', 'Year']] = data['Date'].astype('str').str.extract(r'(\w+)-(\w+) (\d+)', expand=True)

# Map month names to numeric values
data['Start_Month'] = data['Start_Month'].map(month_mapping)
data['End_Month'] = data['End_Month'].map(month_mapping)

# Convert year columns to integers
data['Year'] = data['Year'].astype(int)

# %%
df2=df2.drop(['Year-Month','Month'],axis=1)

# %%
df_merged_test=pd.merge(data,df2, left_on=['Year','Start_Month'], right_on=['Year', 'groupe'],how='left')
df_merged_test.head()
# Out:
#      index  id_product  Region    Country          Site  \
# 0   490548         834    EAJP  Australia  AU_DC_Sydney
# 1   490548         834    EAJP  Australia  AU_DC_Sydney
# 2   490548         834    EAJP  Australia  AU_DC_Sydney
# 3   490548         834    EAJP  Australia  AU_DC_Sydney
# 4  2167957      209101  EUROPE     France  FR_DC_Evreux
#
#                  Operations     Zone    Cluster  Reference proxy  \
# 0  International Operations  Pacific  Australia    reference-145
# 1  International Operations  Pacific  Australia    reference-145
# 2  International Operations  Pacific  Australia    reference-145
# 3  International Operations  Pacific  Australia    reference-145
# 4         France Operations   France     France  reference-13121
#
#   Product  Line proxy  ... Gross capital formation (annual % growth)  \
# 0      Product Line-1  ...                                  3.085818
# 1      Product Line-1  ...                                  3.085818
# 2      Product Line-1  ...                                  3.085818
# 3      Product Line-1  ...                                  3.085818
# 4      Product Line-4  ...                                  3.085818
#
#   Manufacturing, value added (annual % growth) population (2023) growthRate  \
# 0                                     2.240000        26439111.0      0.010
# 1                                     2.240000        26439111.0      0.010
# 2                                     2.240000        26439111.0      0.010
# 3                                     2.240000        26439111.0      0.010
# 4                                     1.528281        64756584.0      0.002
#
#   landAreaKm Start_Month End_Month  Year     GSCPI  groupe
# 0  7692020.0           5         8  2021  2.957795       5
# 1  7692020.0           5         8  2021  2.957795       5
# 2  7692020.0           5         8  2021  2.957795       5
# 3  7692020.0           5         8  2021  2.957795       5
# 4   547557.0           5         7  2023 -1.153880       5
#
# [5 rows x 29 columns]

# %%
df_merged_test.drop_duplicates(inplace=True)

# %%
df_merged_test.drop(['Start_Month','End_Month','Year','groupe'],axis=1,inplace=True)

# %%
df_merged_test
# Out:
#            index  id_product  Region      Country                   Site  \
# 0         490548         834    EAJP    Australia           AU_DC_Sydney
# 4        2167957      209101  EUROPE       France           FR_DC_Evreux
# 7        1999013       40157    EAJP  New Zealand              AU_DC_ALD
# 10        469221      224364   CHINA        China         CN_DC_Shanghai
# 14       1171716      192288  EUROPE      Belgium              NL_DC_HLD
# ...          ...         ...     ...          ...                    ...
# 1713960   849490      114919  EUROPE        Italy          IT_DC_Venaria
# 1713964  1199858      220430   CHINA        China             CN_MF_SSPA
# 1713968  1007643       28215    EAJP    Australia         AU_DC_Brisbane
# 1713972  1647728      178586  EUROPE       Poland  HU_DC_CEELog_Budapest
# 1713976   181981      181981  EUROPE  Netherlands           NL_DC_Venray
#
#                        Operations        Zone                Cluster  \
# 0        International Operations     Pacific              Australia
# 4               France Operations      France                 France
# 7        International Operations     Pacific            New Zealand
# 10               China Operations  China & HK                  China
# 14              Europe Operations        BeNe                Belgium
# ...                           ...         ...                    ...
# 1713960         Europe Operations       Italy                  Italy
# 1713964          China Operations  China & HK                  China
# 1713968  International Operations     Pacific              Australia
# 1713972         Europe Operations        CEEI  Middle Eastern Europe
# 1713976         Europe Operations        BeNe            Netherlands
#
#          Reference proxy Product  Line proxy  ... Month 1 Month 2 Month 3  \
# 0          reference-145      Product Line-1  ...  20 435     610   4 270
# 4        reference-13121      Product Line-4  ...     NaN       0       0
# 7         reference-3409      Product Line-3  ...     NaN       0       4
# 10       reference-19450      Product Line-4  ...       7     150     136
# 14        reference-3686      Product Line-3  ...       0       0       1
# ...                  ...                 ...  ...     ...     ...     ...
# 1713960   reference-6671      Product Line-4  ...       0       2       0
# 1713964  reference-19181      Product Line-5  ...       0       0       0
# 1713968   reference-1966      Product Line-1  ...       0       0       0
# 1713972   reference-7364      Product Line-4  ...       2       0       0
# 1713976   reference-7876      Product Line-4  ...       0       0       0
#
#         GDP (current US$) Gross capital formation (annual % growth)  \
# 0            1.552703e+12                                  3.085818
# 4            2.606698e+12                                  3.085818
# 7            2.606698e+12                                  3.085818
# 10           1.782046e+13                                  3.870000
# 14           5.786041e+11                                  1.580000
# ...                   ...                                       ...
# 1713960      2.114356e+12                                 21.210000
# 1713964      1.796317e+13                                  3.620000
# 1713968      1.675419e+12                                  3.085818
# 1713972      6.881766e+11                                 16.810000
# 1713976      9.097935e+11                                 -6.300000
#
#         Manufacturing, value added (annual % growth) population (2023)  \
# 0                                           2.240000      2.643911e+07
# 4                                           1.528281      6.475658e+07
# 7                                           1.528281      5.228100e+06
# 10                                          1.528281      1.425671e+09
# 14                                          0.200000      1.168614e+07
# ...                                              ...               ...
# 1713960                                    14.070000      5.887076e+07
# 1713964                                     1.528281      1.425671e+09
# 1713968                                     2.540000      2.643911e+07
# 1713972                                     7.220000      4.102607e+07
# 1713976                                    -2.260000      1.761830e+07
#
#         growthRate  landAreaKm     GSCPI
# 0           0.0100   7692020.0  2.957795
# 4           0.0020    547557.0 -1.153880
# 7           0.0083    263310.0 -1.153880
# 10         -0.0002   9424702.9  2.030159
# 14          0.0026     30280.0  3.117173
# ...            ...         ...       ...
# 1713960    -0.0028    295717.0  3.897540
# 1713964    -0.0002   9424702.9  3.117173
# 1713968     0.0100   7692020.0  3.117173
# 1713972     0.0293    306130.0  1.111621
# 1713976     0.0031     33670.0  0.784687
#
# [440743 rows x 25 columns]

# %% [markdown]
# ## 2/ Cleaning the new dataset

# %%
#Read the data
df_new=df_merged_test

# %%
# Converting months to numerical values
df_new['Month 1'] = df_new['Month 1'].astype(str).str.replace(' ', '').astype(float)
df_new['Month 2'] = df_new['Month 2'].astype(str).str.replace(' ', '').astype(float)
df_new['Month 3'] = df_new['Month 3'].astype(str).str.replace(' ', '').astype(float)

# %%
# Replacing the NaN value in 'Product Life cycel status' column which means Activelifecycle)
df_new['Product Life cycel status'].fillna('active', inplace=True)

# %% [markdown]
# ### Replacing Missing values

# %% [markdown]
# #### missing values in Month 1 of the original dataset

# %%
may_jul_2023_data = df_new[df_new['Date'] == 'jan-apr 2023'][['id_product','Month 3']]

# Renommer la colonne "Month 4" pour éviter un conflit lors de la fusion
may_jul_2023_data = may_jul_2023_data.rename(columns={'Month 3': 'New_Month_1'})

# Fusionner les deux DataFrames sur la colonne "id_product"
df_new = pd.merge(df_new, may_jul_2023_data, on=['id_product'], how='left')

# Remplacer les valeurs NaN dans "Month 1" par les valeurs correspondantes dans "New_Month_1"
df_new['Month 1'].fillna(df_new['New_Month_1'], inplace=True)

# Supprimer la colonne temporaire "New_Month_1"
df_new.drop(columns=['New_Month_1'], inplace=True)

# %%
df_new['Month 1'].fillna(df_new[['Month 2','Month 3']].mean(axis=1), inplace=True)

# %% [markdown]
# #### missing values in the new added features

# %%
df_new.isna().sum()
# Out:
# index                                              0
# id_product                                         0
# Region                                             0
# Country                                            0
# Site                                               0
# Operations                                         0
# Zone                                               0
# Cluster                                            0
# Reference proxy                                    0
# Product  Line proxy                                0
# Division proxy                                     0
# Customer Persona proxy                             0
# Strategic Product Family proxy                     0
# Product Life cycel status                          0
# Date                                               0
# Month 1                                            0
# Month 2                                            0
# Month 3                                            0
# GDP (current US$)                               6712
# Gross capital formation (annual % growth)       6712
# Manufacturing, value added (annual % growth)    6712
# population (2023)                               2967
# growthRate                                      2967
# landAreaKm                                      2967
# GSCPI                                              0
# dtype: int64

# %%
gdp= df_new[['GDP (current US$)']].mean()
gdp
# Out:
# GDP (current US$)    6.400696e+12
# dtype: float64

# %%
df_new['GDP (current US$)'].fillna(6.400696e+12,inplace=True)

# %%
gc= df_new[['Gross capital formation (annual % growth)']].mean()
gc
# Out:
# Gross capital formation (annual % growth)    4.171108
# dtype: float64

# %%
df_new['Gross capital formation (annual % growth)'].fillna(4.171108, inplace=True)

# %%
mv= df_new[['Manufacturing, value added (annual % growth)']].mean()
mv
# Out:
# Manufacturing, value added (annual % growth)    2.324732
# dtype: float64

# %%
df_new['Manufacturing, value added (annual % growth)'].fillna(2.324732, inplace=True)

# %%
pop = df_new[['population (2023)']].mean()
gRate = df_new[['growthRate']].mean()
lKm = df_new[['landAreaKm']].mean()

# %%
pop
# Out:
# population (2023)    2.263951e+08
# dtype: float64

# %%
gRate
# Out:
# growthRate    0.004526
# dtype: float64

# %%
lKm
# Out:
# landAreaKm    3.914891e+06
# dtype: float64

# %%
df_new['population (2023)'].fillna(2.263951e+08, inplace=True)
df_new['growthRate'].fillna(0.004526, inplace=True)
df_new['landAreaKm'].fillna(3.914891e+06, inplace=True)

# %%
df_new.isna().sum()
# Out:
# index                                           0
# id_product                                      0
# Region                                          0
# Country                                         0
# Site                                            0
# Operations                                      0
# Zone                                            0
# Cluster                                         0
# Reference proxy                                 0
# Product  Line proxy                             0
# Division proxy                                  0
# Customer Persona proxy                          0
# Strategic Product Family proxy                  0
# Product Life cycel status                       0
# Date                                            0
# Month 1                                         0
# Month 2                                         0
# Month 3                                         0
# GDP (current US$)                               0
# Gross capital formation (annual % growth)       0
# Manufacturing, value added (annual % growth)    0
# population (2023)                               0
# growthRate                                      0
# landAreaKm                                      0
# GSCPI                                           0
# dtype: int64

# %%
df_new.drop(['index'],axis=1,inplace=True)

# %% [markdown]
# #### Removing highly-correlated features ('Region','Country','Site','Operations','Zone' ) with 'Cluster'

# %%
df_new.drop(['Region','Country','Site','Operations','Zone'],axis=1,inplace=True)

# %%
df_new
# Out:
#         id_product                Cluster  Reference proxy  \
# 0              834              Australia    reference-145
# 1           209101                 France  reference-13121
# 2            40157            New Zealand   reference-3409
# 3           224364                  China  reference-19450
# 4           192288                Belgium   reference-3686
# ...            ...                    ...              ...
# 440738      114919                  Italy   reference-6671
# 440739      220430                  China  reference-19181
# 440740       28215              Australia   reference-1966
# 440741      178586  Middle Eastern Europe   reference-7364
# 440742      181981            Netherlands   reference-7876
#
#        Product  Line proxy Division proxy    Customer Persona proxy  \
# 0           Product Line-1     Division-1   Customer Segmentation-8
# 1           Product Line-4     Division-3  Customer Segmentation-66
# 2           Product Line-3     Division-2   Customer Segmentation-4
# 3           Product Line-4     Division-3   Customer Segmentation-4
# 4           Product Line-3     Division-2   Customer Segmentation-4
# ...                    ...            ...                       ...
# 440738      Product Line-4     Division-3  Customer Segmentation-15
# 440739      Product Line-5     Division-3  Customer Segmentation-13
# 440740      Product Line-1     Division-1   Customer Segmentation-6
# 440741      Product Line-4     Division-3  Customer Segmentation-14
# 440742      Product Line-4     Division-3  Customer Segmentation-17
#
#        Strategic Product Family proxy Product Life cycel status          Date  \
# 0          Strategic Product Family-1                       EOL  may-aug 2021
# 1          Strategic Product Family-9                    active  may-jul 2023
# 2          Strategic Product Family-7                    active  may-jul 2023
# 3         Strategic Product Family-13                    active  jan-apr 2021
# 4          Strategic Product Family-7                  RaMPDOWN  jan-apr 2022
# ...                               ...                       ...           ...
# 440738     Strategic Product Family-9                    active  sep-dec 2021
# 440739    Strategic Product Family-15                    active  jan-apr 2022
# 440740     Strategic Product Family-4                    active  jan-apr 2022
# 440741     Strategic Product Family-9                    active  sep-dec 2022
# 440742     Strategic Product Family-9                    active  sep-dec 2020
#
#         Month 1  Month 2  Month 3  GDP (current US$)  \
# 0       20435.0    610.0   4270.0       1.552703e+12
# 1           0.0      0.0      0.0       2.606698e+12
# 2           2.0      0.0      4.0       2.606698e+12
# 3           7.0    150.0    136.0       1.782046e+13
# 4           0.0      0.0      1.0       5.786041e+11
# ...         ...      ...      ...                ...
# 440738      0.0      2.0      0.0       2.114356e+12
# 440739      0.0      0.0      0.0       1.796317e+13
# 440740      0.0      0.0      0.0       1.675419e+12
# 440741      2.0      0.0      0.0       6.881766e+11
# 440742      0.0      0.0      0.0       9.097935e+11
#
#         Gross capital formation (annual % growth)  \
# 0                                        3.085818
# 1                                        3.085818
# 2                                        3.085818
# 3                                        3.870000
# 4                                        1.580000
# ...                                           ...
# 440738                                  21.210000
# 440739                                   3.620000
# 440740                                   3.085818
# 440741                                  16.810000
# 440742                                  -6.300000
#
#         Manufacturing, value added (annual % growth)  population (2023)  \
# 0                                           2.240000       2.643911e+07
# 1                                           1.528281       6.475658e+07
# 2                                           1.528281       5.228100e+06
# 3                                           1.528281       1.425671e+09
# 4                                           0.200000       1.168614e+07
# ...                                              ...                ...
# 440738                                     14.070000       5.887076e+07
# 440739                                      1.528281       1.425671e+09
# 440740                                      2.540000       2.643911e+07
# 440741                                      7.220000       4.102607e+07
# 440742                                     -2.260000       1.761830e+07
#
#         growthRate  landAreaKm     GSCPI
# 0           0.0100   7692020.0  2.957795
# 1           0.0020    547557.0 -1.153880
# 2           0.0083    263310.0 -1.153880
# 3          -0.0002   9424702.9  2.030159
# 4           0.0026     30280.0  3.117173
# ...            ...         ...       ...
# 440738     -0.0028    295717.0  3.897540
# 440739     -0.0002   9424702.9  3.117173
# 440740      0.0100   7692020.0  3.117173
# 440741      0.0293    306130.0  1.111621
# 440742      0.0031     33670.0  0.784687
#
# [440743 rows x 19 columns]

# %%
df_new.to_csv("test_preprocessing_clean.csv", index=False, sep=';')
